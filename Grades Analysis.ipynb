# %%
# Import necessary libraries 
import pandas as pd

# %%
# read the dataset & summarize it
test_results = pd.read_csv("datasets/TestAnalysis/test_scores.csv")
print(test_results.head())
print()

test_results.describe()
# Out:
#   Participant_Code  Term  Test Instructor LetterGrade  PercentGrade   Q1   Q2  \
# 0              KEY   NaN   NaN        NaN         NaN          0.00    E    D
# 1              NaN   NaN   NaN        NaN         NaN           NaN  NaN  NaN
# 2               22   1.0  Post          A           D         54.83    D    C
# 3               50   1.0   Pre          A           F         12.41    A  NaN
# 4               82   1.0   Pre          A          B+         84.94    C    C
#
#     Q3   Q4  ...  Q18  Q19  Q20  Q21  Q22  Q23  Q24  Q25  Q26  Q27
# 0    D    E  ...    B    C    B    D    C    C    D    B    A    D
# 1  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    B    C  ...    C    A    C    A    C    A    B    A    B    A
# 3    A  NaN  ...  NaN    A    B    A  NaN    C  NaN  NaN  NaN  NaN
# 4    A    C  ...    D  NaN    B    A    D    C    A    E    B    B
#
# [5 rows x 33 columns]
#              Term  PercentGrade
# count  147.000000    148.000000
# ...

# %%
# Set the index to the participant code
test_results.set_index('Participant_Code')

test_results.head()
# Out:
#   Participant_Code  Term  Test Instructor LetterGrade  PercentGrade   Q1   Q2  \
# 0              KEY   NaN   NaN        NaN         NaN          0.00    E    D
# 1              NaN   NaN   NaN        NaN         NaN           NaN  NaN  NaN
# 2               22   1.0  Post          A           D         54.83    D    C
# 3               50   1.0   Pre          A           F         12.41    A  NaN
# 4               82   1.0   Pre          A          B+         84.94    C    C
#
#     Q3   Q4  ...  Q18  Q19  Q20  Q21  Q22  Q23  Q24  Q25  Q26  Q27
# 0    D    E  ...    B    C    B    D    C    C    D    B    A    D
# 1  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    B    C  ...    C    A    C    A    C    A    B    A    B    A
# 3    A  NaN  ...  NaN    A    B    A  NaN    C  NaN  NaN  NaN  NaN
# 4    A    C  ...    D  NaN    B    A    D    C    A    E    B    B
#
# [5 rows x 33 columns]

# %%
# Lets check how many null values there are
test_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Participant_Code  148 non-null    object
#  1   Term              147 non-null    float64
#  2   Test              147 non-null    object
#  3   Instructor        147 non-null    object
#  4   LetterGrade       147 non-null    object
#  5   PercentGrade      148 non-null    float64
#  6   Q1                115 non-null    object
#  7   Q2                98 non-null     object
#  8   Q3                112 non-null    object
#  9   Q4                91 non-null     object
#  10  Q5                123 non-null    object
#  11  Q6                108 non-null    object
#  12  Q7                80 non-null     object
#  13  Q8                113 non-null    object
#  14  Q9                87 non-null     object
#  15  Q10               100 non-null    object
# ...

# %% [markdown]
# #### Reading the data with pandas

# %%
test_results.head()
# Out:
#   Participant_Code  Term  Test Instructor LetterGrade  PercentGrade   Q1   Q2  \
# 0              KEY   NaN   NaN        NaN         NaN          0.00    E    D
# 1              NaN   NaN   NaN        NaN         NaN           NaN  NaN  NaN
# 2               22   1.0  Post          A           D         54.83    D    C
# 3               50   1.0   Pre          A           F         12.41    A  NaN
# 4               82   1.0   Pre          A          B+         84.94    C    C
#
#     Q3   Q4  ...  Q18  Q19  Q20  Q21  Q22  Q23  Q24  Q25  Q26  Q27
# 0    D    E  ...    B    C    B    D    C    C    D    B    A    D
# 1  NaN  NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2    B    C  ...    C    A    C    A    C    A    B    A    B    A
# 3    A  NaN  ...  NaN    A    B    A  NaN    C  NaN  NaN  NaN  NaN
# 4    A    C  ...    D  NaN    B    A    D    C    A    E    B    B
#
# [5 rows x 33 columns]

# %%
# We want to drop the second row because it has not data 
test_results = test_results.drop(labels=1, axis=0)
test_results.head()
# Out:
#   Participant_Code  Term  Test Instructor LetterGrade  PercentGrade Q1   Q2  \
# 0              KEY   NaN   NaN        NaN         NaN          0.00  E    D
# 2               22   1.0  Post          A           D         54.83  D    C
# 3               50   1.0   Pre          A           F         12.41  A  NaN
# 4               82   1.0   Pre          A          B+         84.94  C    C
# 5               82   1.0  Post          A          B+         84.94  B    D
#
#   Q3   Q4  ...  Q18  Q19 Q20 Q21  Q22 Q23  Q24  Q25  Q26  Q27
# 0  D    E  ...    B    C   B   D    C   C    D    B    A    D
# 2  B    C  ...    C    A   C   A    C   A    B    A    B    A
# 3  A  NaN  ...  NaN    A   B   A  NaN   C  NaN  NaN  NaN  NaN
# 4  A    C  ...    D  NaN   B   A    D   C    A    E    B    B
# 5  D    D  ...    C    E   B   C    C   A  NaN    D    D    C
#
# [5 rows x 33 columns]

# %%
test_results = test_results.fillna('X')
test_results.head()
# Out:
#   Participant_Code Term  Test Instructor LetterGrade  PercentGrade Q1 Q2 Q3  \
# 0              KEY    X     X          X           X          0.00  E  D  D
# 2               22  1.0  Post          A           D         54.83  D  C  B
# 3               50  1.0   Pre          A           F         12.41  A  X  A
# 4               82  1.0   Pre          A          B+         84.94  C  C  A
# 5               82  1.0  Post          A          B+         84.94  B  D  D
#
#   Q4  ... Q18 Q19 Q20 Q21 Q22 Q23 Q24 Q25 Q26 Q27
# 0  E  ...   B   C   B   D   C   C   D   B   A   D
# 2  C  ...   C   A   C   A   C   A   B   A   B   A
# 3  X  ...   X   A   B   A   X   C   X   X   X   X
# 4  C  ...   D   X   B   A   D   C   A   E   B   B
# 5  D  ...   C   E   B   C   C   A   X   D   D   C
#
# [5 rows x 33 columns]

# %%
# Create a box plot for the post test scores of the children
is_post = test_results['Test'] == 'Post'
is_post = test_results[is_post]
is_post.plot(kind='box', x = 'Test', y = 'PercentGrade', title='Post Test Grades')
is_post.set_xlabel=('Post')
is_post.set_ylabel=('Grade')

# %%
# Now create a box plot for the pre test scores and compare with the post
is_pre = test_results['Test'] == 'Pre'
is_pre = test_results[is_pre]
is_pre.plot(kind='box', x = 'Test', y = 'PercentGrade')
# Out:
# <AxesSubplot:>

# %%
print(is_post['PercentGrade'].mean())
print(is_pre['PercentGrade'].mean())
print(is_post['PercentGrade'].mean() - is_pre['PercentGrade'].mean())
# Out:
# 85.32617647058824
# 76.91518987341775
# 8.410986597170492

# %% [markdown]
# As we can see there was more outliers in with the pre test scores than the post test cores. We can then inffer that students preformed better if they took a practice exam. Students preforms an average of about 8.41% better if they took a practice test which is almost a whole letter grade.

# %%
# Graph both box plots in the same graph
results = test_results.drop(labels=0, axis=0)
results.boxplot(column='PercentGrade', by ='Test')
# Out:
# <AxesSubplot:title={'center':'PercentGrade'}, xlabel='Test'>

# %%
test_results.head()
# Out:
#   Participant_Code Term  Test Instructor LetterGrade  PercentGrade Q1 Q2 Q3  \
# 0              KEY    X     X          X           X          0.00  E  D  D
# 2               22  1.0  Post          A           D         54.83  D  C  B
# 3               50  1.0   Pre          A           F         12.41  A  X  A
# 4               82  1.0   Pre          A          B+         84.94  C  C  A
# 5               82  1.0  Post          A          B+         84.94  B  D  D
#
#   Q4  ... Q18 Q19 Q20 Q21 Q22 Q23 Q24 Q25 Q26 Q27
# 0  E  ...   B   C   B   D   C   C   D   B   A   D
# 2  C  ...   C   A   C   A   C   A   B   A   B   A
# 3  X  ...   X   A   B   A   X   C   X   X   X   X
# 4  C  ...   D   X   B   A   D   C   A   E   B   B
# 5  D  ...   C   E   B   C   C   A   X   D   D   C
#
# [5 rows x 33 columns]

# %%
answer_key = test_results.loc[0:0]
answer_key = answer_key.loc[:,'Q1': 'Q27']
answer_key.head(1)
# Out:
#   Q1 Q2 Q3 Q4 Q5 Q6 Q7 Q8 Q9 Q10  ... Q18 Q19 Q20 Q21 Q22 Q23 Q24 Q25 Q26 Q27
# 0  E  D  D  E  A  A  A  E  B   D  ...   B   C   B   D   C   C   D   B   A   D
#
# [1 rows x 27 columns]

# %%
student_test = test_results.loc[:, 'Q1':'Q27']
student_test = student_test.drop(labels=0, axis=0)
student_test['Q1']
temp = 0

for answer, index in student_test['Q1']:
    print(answer)
    if(answer == answer_key['Q1'][0]):
        temp += 1

print(temp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [30], in <cell line: 6>()
#       3 student_test['Q1']
#       4 temp = 0
# ----> 6 for answer, index in student_test['Q1']:
#       7     print(answer)
#       8     if(answer == answer_key['Q1'][0]):
#
# ValueError: not enough values to unpack (expected 2, got 1)
