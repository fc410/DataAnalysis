# %% [markdown]
# # Reading the data with pandas:

# %%
import pandas as pd

# %%
data = pd.read_csv("data.csv")

data.describe()
# Out:
#              Term  PercentGrade
# count  147.000000    147.000000
# mean     1.326531     80.805986
# std      0.470547     22.671825
# min      1.000000      0.000000
# 25%      1.000000     73.620000
# 50%      1.000000     87.810000
# 75%      2.000000     97.170000
# max      2.000000    106.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Participant Code  148 non-null    object
#  1   Term              147 non-null    float64
#  2   Test              147 non-null    object
#  3   Instructor        147 non-null    object
#  4   LetterGrade       147 non-null    object
#  5   PercentGrade      147 non-null    float64
#  6   Q1                115 non-null    object
#  7   Q2                98 non-null     object
#  8   Q3                112 non-null    object
#  9   Q4                91 non-null     object
#  10  Q5                123 non-null    object
#  11  Q6                108 non-null    object
#  12  Q7                80 non-null     object
#  13  Q8                113 non-null    object
#  14  Q9                87 non-null     object
#  15  Q10               100 non-null    object
# ...

# %% [markdown]
# # Cleaning up the empty data

# %%
#data["Q1"].fillna("No answer", inplace=True)

for column in data.loc[:,"Q1":"Q27"]:
     data.fillna(0, inplace=True)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Participant Code  149 non-null    object
#  1   Term              149 non-null    float64
#  2   Test              149 non-null    object
#  3   Instructor        149 non-null    object
#  4   LetterGrade       149 non-null    object
#  5   PercentGrade      149 non-null    float64
#  6   Q1                149 non-null    object
#  7   Q2                149 non-null    object
#  8   Q3                149 non-null    object
#  9   Q4                149 non-null    object
#  10  Q5                149 non-null    object
#  11  Q6                149 non-null    object
#  12  Q7                149 non-null    object
#  13  Q8                149 non-null    object
#  14  Q9                149 non-null    object
#  15  Q10               149 non-null    object
# ...

# %%
data
# Out:
#     Participant Code  Term  Test Instructor LetterGrade  PercentGrade Q1 Q2  \
# 0                KEY   0.0     0          0           0          0.00  E  D
# 1                  0   0.0     0          0           0          0.00  0  0
# 2                 22   1.0  Post          A           D         54.83  D  C
# 3                 50   1.0   Pre          A           F         12.41  A  0
# 4                 82   1.0   Pre          A          B+         84.94  C  C
# ..               ...   ...   ...        ...         ...           ... .. ..
# 144               37   2.0  Post          B           A         97.72  A  D
# 145               42   2.0  Post          B          B+         87.81  D  0
# 146               42   2.0   Pre          B          B+         87.81  C  C
# 147               79   2.0   Pre          B          B+         86.68  D  0
# 148               79   2.0  Post          B          B+         86.68  B  E
#
#     Q3 Q4  ... Q18 Q19 Q20 Q21 Q22 Q23 Q24 Q25 Q26 Q27
# ...

# %% [markdown]
# droping the collumn with no data

# %%
data.drop(1) #droping row[1]
# Out:
#     Participant Code  Term  Test Instructor LetterGrade  PercentGrade Q1 Q2  \
# 0                KEY   0.0     0          0           0          0.00  E  D
# 2                 22   1.0  Post          A           D         54.83  D  C
# 3                 50   1.0   Pre          A           F         12.41  A  0
# 4                 82   1.0   Pre          A          B+         84.94  C  C
# 5                 82   1.0  Post          A          B+         84.94  B  D
# ..               ...   ...   ...        ...         ...           ... .. ..
# 144               37   2.0  Post          B           A         97.72  A  D
# 145               42   2.0  Post          B          B+         87.81  D  0
# 146               42   2.0   Pre          B          B+         87.81  C  C
# 147               79   2.0   Pre          B          B+         86.68  D  0
# 148               79   2.0  Post          B          B+         86.68  B  E
#
#     Q3 Q4  ... Q18 Q19 Q20 Q21 Q22 Q23 Q24 Q25 Q26 Q27
# ...

# %%
data.shape
# Out:
# (149, 33)

# %%
data.describe()
# Out:
#              Term  PercentGrade
# count  149.000000    149.000000
# mean     1.308725     79.721342
# std      0.491816     24.374558
# min      0.000000      0.000000
# 25%      1.000000     73.580000
# 50%      1.000000     87.190000
# 75%      2.000000     96.810000
# max      2.000000    106.000000

# %%
data.isnull().any()
# Out:
# Participant Code    False
# Term                False
# Test                False
# Instructor          False
# LetterGrade         False
# PercentGrade        False
# Q1                  False
# Q2                  False
# Q3                  False
# Q4                  False
# Q5                  False
# Q6                  False
# Q7                  False
# Q8                  False
# Q9                  False
# Q10                 False
# Q11                 False
# Q12                 False
# Q13                 False
# Q14                 False
# Q15                 False
# Q16                 False
# Q17                 False
# Q18                 False
# Q19                 False
# Q20                 False
# Q21                 False
# Q22                 False
# Q23                 False
# Q24                 False
# Q25                 False
# Q26                 False
# Q27                 False
# dtype: bool

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
data["PercentGrade"].replace({"No answer": 0}, inplace=True)
# Out:
# ------------------------------------------------------
# TypeError            Traceback (most recent call last)
# <ipython-input-24-b8117e2bf617> in <module>
# ----> 1 data["PercentGrade"].replace({"No answer": 0}, inplace=True)
#
# c:\users\cresp\onedrive\desktop\bin\data-analysis\venv\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4170         method="pad",
#    4171     ):
# -> 4172         return super().replace(
#    4173             to_replace=to_replace,
#    4174             value=value,
#
# c:\users\cresp\onedrive\desktop\bin\data-analysis\venv\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6643                 to_replace, value = keys, values
#    6644
# -> 6645             return self.replace(
#    6646                 to_replace, value, inplace=inplace, limit=limit, regex=regex
#    6647             )
#
# ...

# %%
data
# Out:
#     Participant Code  Term  Test Instructor LetterGrade  PercentGrade Q1 Q2  \
# 0                KEY   0.0     0          0           0          0.00  E  D
# 1                  0   0.0     0          0           0          0.00  0  0
# 2                 22   1.0  Post          A           D         54.83  D  C
# 3                 50   1.0   Pre          A           F         12.41  A  0
# 4                 82   1.0   Pre          A          B+         84.94  C  C
# ..               ...   ...   ...        ...         ...           ... .. ..
# 144               37   2.0  Post          B           A         97.72  A  D
# 145               42   2.0  Post          B          B+         87.81  D  0
# 146               42   2.0   Pre          B          B+         87.81  C  C
# 147               79   2.0   Pre          B          B+         86.68  D  0
# 148               79   2.0  Post          B          B+         86.68  B  E
#
#     Q3 Q4  ... Q18 Q19 Q20 Q21 Q22 Q23 Q24 Q25 Q26 Q27
# ...

# %% [markdown]
# Now lets see what the average grade is both classes by percentage

# %%
plt.figure(figsize=(15,10))
plt.tight_layout()
seabornInstance.distplot(data['PercentGrade'])
